# %% [markdown]
# <a href="https://colab.research.google.com/github/Kolpi03/Machine-learning/blob/main/House_price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
print("Python version:", sys.version)

import numpy as np
print("NumPy version:", np.__version__)
# Out:
# Python version: 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]
# NumPy version: 2.0.2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_train =np.array([1.0, 2.0])
y_train= np.array([300.0,500.0])
print(f"x_train = {x_train}")
print(f"y_train ={y_train}")
# Out:
# x_train = [1. 2.]
# y_train =[300. 500.]

# %%
m=x_train.shape[0]
print(f"Number of training examples is:{m}")
# Out:
# Number of training examples is:2

# %%
m=len(x_train)

print(f"Number of training examples is:{m}")
# Out:
# Number of training examples is:2

# %%
i=0;
x_i=x_train[i]
y_i=y_train[i]
print(f"{i}th training example:({x_i},{y_i})")
# Out:
# 0th training example:(1.0,300.0)

# %%
plt.figure(figsize=(4, 3))
plt.scatter(x_train,y_train,marker='x',c='r')
plt.title("Housing Prices")
plt.ylabel('price (in 1000 of dollars)')
plt.xlabel('size (in 1000 ft)')
plt.show()

# %%
w=100
b=100

# %%
def compute_model_output(x,w,b):
  m=x.shape[0]
  f_wb=np.zeros(m)
  for i in range(m):
     f_wb[i]=w*x[i]+b
  return f_wb

# %%
tmp_f_wb=compute_model_output(x_train,w,b,)
plt.plot(x_train, tmp_f_wb, c='b', label='Our prediction')
plt.scatter(x_train,y_train,marker='x',c='r',label='Actual values')
plt.title('Housing Price')
plt.ylabel('price(in 1000s of dollars)')
plt.xlabel('sIZE(1000 sq feet)')
plt.legend()
plt.figure(figsize=(4, 3))
plt.show()

# %%
##prediction
w=100
b=100
x_i=1.2
cost_1200sqft=w*x_i+b
print(f"${cost_1200sqft:.0f} thousand dollars")
# Out:
# $220 thousand dollars

# %%
plt.plot(x_train, tmp_f_wb, c='b', label='Our Prediction')
plt.scatter(x_train, y_train, c='r', marker='x', label='Actual Values')
x_i = 1.2
price = w * x_i + b
plt.scatter(x_i, price, c='g', marker='o', label='Prediction for 1.2')

plt.title("Housing Prices")
plt.xlabel("Size (1000 sqft)")
plt.ylabel("Price (in 1000s of dollars)")
plt.legend()
plt.show()


x_i = np.array([1.2])
pred=compute_model_output(x_i,w,b,)
print(f"Predicted price: ${pred[0]:.0f} thousand dollars")
# Out:
# Predicted price: $340 thousand dollars
